# %%
import requests, json, pandas

# %%
{'method': 'TRANSACTIONS',
 'callback_type': 'TRANSACTIONS', 
 'callback_code': 'INITIAL_TRANSACTIONS', 
 'type': 'CALLBACK', 
 'code': 'INITIAL_TRANSACTIONS', 
 'callbackURL': 'https://d79a65e7c014.ngrok.io/api/tx/callback/', 
 'new_transactions': 30, 
 'env': 'production-sandbox', 
 'owner': '5eda1df311475d0826ac1850', 
 'status': 'is_done', 
 'started_at': '2020-07-06T21:48:48.132Z', 
 'ended_at': '2020-07-06T21:48:48.132Z', 
 'message': 'Transactions fetched successfully!', 
 'record': '5f039c243103140b668e92fb', 
 'callback_url': 'https://api.okra.ng/v1/callback?record=5f039c243103140b668e92fb&method=TRANSACTIONS', 
 'bankId': '5d6fe57a4099cc4b210bbeb3', 
 'customerId': '5ed3d67b8723c11444c43283', 
 'with_income': False, 
 'account': 'EE36000500', 
 'options': {}}

# %%
{'method': 'TRANSACTIONS', 
 'callback_type': 'TRANSACTIONS',
 'callback_code': 'INITIAL_TRANSACTIONS',
 'type': 'CALLBACK', 
 'code': 'INITIAL_TRANSACTIONS', 
 'callbackURL': 'https://d79a65e7c014.ngrok.io/api/tx/callback/', 
 'new_transactions': 56, 
 'env': 'production-sandbox', 
 'owner': '5eda1df311475d0826ac1850', 
 'status': 'is_done', 
 'started_at': '2020-07-06T22:42:26.017Z', 
 'ended_at': '2020-07-06T22:42:26.017Z', 
 'message': 'Transactions fetched successfully!', 
 'record': '5f03a8b95a63fd0c4a54cacb', 
 'callback_url': 'https://api.okra.ng/v1/callback?record=5f03a8b95a63fd0c4a54cacb&method=TRANSACTIONS', 
 'bankId': '5d6fe57a4099cc4b210bbeb8', 
 'customerId': '5eae1ec8a400e208b3b888cd', 
 'with_income': False, 
 'account': 'LI70550515', 
 'options': {'username': 'uchencho'}}

# %%
x = {'method': 'BALANCE', 
 'callback_type': 'BALANCE', 
 'callback_code': 'PRODUCT_IS_READY', 
 'type': 'CALLBACK', 
 'code': 'PRODUCT_IS_READY', 
 'callbackURL': 'https://d79a65e7c014.ngrok.io/api/tx/callback/', 
 'env': 'production-sandbox', 
 'owner': '5eda1df311475d0826ac1850', 
 'status': 'is_done', 
 'started_at': '2020-07-06T23:25:09.087Z', 
 'ended_at': '2020-07-06T23:25:09.087Z', 
 'message': 'Succesfully fetched updated balance!', 
 'record': '5f03b2c28b1d840dc57b7f41', 
 'callback_url': 'https://api.okra.ng/v1/callback?record=5f03b2c28b1d840dc57b7f41&method=BALANCE', 
 'bankId': '5d6fe57a4099cc4b210bbeb9', 
 'customerId': '5ef09108658acd0d06ae06b9', 
 'options': {'username': 'uchencho', 'passed_id': '10'}}

# %%
x.get('optionss') == None
# Out:
# True

# %%
api_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU'
api_url = 'https://api.okra.ng/sandbox/v1/transaction/getByCustomer'
headers = {'Content-Type': 'application/json',
           'Authorization': 'Bearer {0}'.format(api_token),
          }

inp_dict = {
    'api_token' : 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU'
}


response = requests.post(
    api_url,
    headers = headers,
    json={
        "customer": "5ed3d67b8723c11444c43283",
        "page": 2
    })

# %% [markdown]
# - Name of python file will be Okra_python

# %%
class Okra_Cust():
    """
    Okra offers a path for a customer to successfully verify their bank. 
    The customer enters their credentials and are authenticated immediately.
    """
    import requests
    
    def __init__(self, inp_dict):
        self.api_token = inp_dict['api_token']
        
    def get_customer(self, data_):
        url = 'https://api.okra.ng/sandbox/v1/transaction/getByCustomer'
        headers = {'Content-Type': 'application/json',
           'Authorization': f'Bearer {self.api_token}'
          }
        resp = requests.post(url, headers = headers, json=data_)
        return resp.text

# %%
class Okra_Auth():
    """
    Okra offers a path for a customer to successfully verify their bank. 
    The customer enters their credentials and are authenticated immediately.
    
    https://docs.okra.ng/products/auth
    
    """
    
    
    def __init__(self, token, base_url):
        
        """
        Import requests on initialization
        Set the headers based on api token
        Set needed attributes
        """
        
        import requests
        
        self.api_token = token
        self.base_url = base_url
        self.headers = {'Content-Type': 'application/json',
                          'Authorization' : self.api_token}
        self.requests = requests
     
    def retrieve_auth(self):
        
        """
        Retrieve Bank details
        """
        url = self.base_url + "products/auths"
        resp = self.requests.post(url, headers = self.headers)
        return resp.json()
    
    
    def getbyID(self, idx, page=1, limit=1):
        
        """
        fetch authentication info using the id of the authentication record.
        
        Args : "idx" (string): "5rggfdfghjkl4567"
        """
        url = self.base_url + "auth/getById"
        data_ = {"id": idx, "page": page, "limit":limit}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyOptions(self, first_name, last_name, page=1, limit=1):
        """
        fetch authentication info using the options metadata you provided when setting up the widget.
        
        Args : "first_name" (string): "Uchencho",
               "last_name" (string): "Nwa Alozie"
        """
        url = self.base_url + "auth/byOptions"
        data_ = {"page": page, "limit":limit, 
                "options":{"first_name": first_name, "last_name": last_name}}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyCustomer(self, customer_id, page=1, limit=1):
        """
        fetch authentication info using the customer id.
        
        Args : "customer_id" (string): "5rggfdfghjkl4567",
        """
        url = self.base_url + "auth/getByCustomer"
        data_ = {"page": page, "limit":limit, "customer":customer_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyDate(self, from_, to_, page=1, limit=1):
        """
        fetch authentication info using a date range.
        
        Args : "to_" (string): "2020-4-02",
                "from_" (string): "2020-01-01"
        """
        url = self.base_url + "auth/getByDate"
        data_ = {"page": page, "limit":limit, "to":to_, "from":from_}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyBank(self, bank_id, page=1, limit=1):
        """
        fetch authentication info using the bank id.
        
        Args : "bank_id" (string): "5rggfdfghjkl4567",
        """
        url = self.base_url + "auth/getByBank"
        data_ = {"page": page, "limit":limit, "bank":bank_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyCustomerDate(self, customer_id, from_, to_, page=1, limit=1):
        """
        fetch authentication for a customer using a date range and customer id.
        
        Args : "customer":"5rggfdfghjkl4567",
                "to_" (string): "2020-4-02",
                "from_" (string): "2020-01-01"
        """
        url = self.base_url + "auth/getByDateCustomer"
        data_ = {"page": page, "limit":limit, "to":to_, "from":from_, "customer":customer_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()

# %%
inp_dict = {
    'api_token' : 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU',
    'base_url' : 'https://api.okra.ng/sandbox/v1/
}
data = {
        "customer": "5ed3d67b8723c11444c43283",
        "page": 2
    }
Okra_Auth(inp_dict).get_customer(data)
# Out:
# {"status":"success","message":"Transactions retrieved succesfully","data":{"pagination":{"totalDocs":132,"limit":20,"hasPrevPage":true,"hasNextPage":true,"page":2,"totalPages":7,"pagingCounter":21,"prevPage":1,"nextPage":3},"transaction":[{"notes":{"topics":["c"],"places":["c"],"people":["c"],"actions":["b"],"subjects":["b"],"preopositions":["a"],"desc":"Aliquid veniam laudantium ut sunt illo qui neque neque nostrum."},"fetched":["5eda1df311475d0826ac1850"],"record":["5ee5028620ec110c6194f85d"],"_id":"5ee502d120ec110c6194f889","branch":"OKQUASV1","cleared_date":"2020-06-12T18:13:10.311Z","unformatted_cleared_date":"12-06-2020","code":"y","credit":null,"debit":30373,"trans_date":"2020-06-12T19:10:46.300Z","unformatted_trans_date":"12-06-2020","customer":{"_id":"5ed3d67b8723c11444c43283","name":"Elizabeth Agusto"},"account":{"_id":"5ee5029f5a297caf4ce25ef3","name":"Checking Account"},"env":"production-sandbox","bank":{"name":"Guaranty Trust Bank","logo":"https://okra-images.s3.eu-west-3.amazonaws.com/GT+Bank.svg","icon":"https://okra-images.s3.eu-west-3.amazonaws.com/Guaranty+Trust+Bank+Logo+Color.svg","status":"healthy"},"created_at":"2020-06-13T16:46:09.369Z","last_updated":"2020-06-13T16:46:09.100Z","__v":0},{"notes":{"topics":["b"],"places":["a"],"people":["b"],"actions":["b"],"subjects":["b"],"preopositions":["b"],"desc":"Maiores eveniet vitae."},"fetched":["5eda1df311475d0826ac1850"],"record":["5ee5028620ec110c6194f85d"],"_id":"5ee502d120ec110c6194f887","branch":"NHIAPRG1","cleared_date":"2020-06-13T10:20:46.202Z","unformatted_cleared_date":"13-06-2020","code":"4","credit":null,"debit":46215,"trans_date":"2020-06-13T14:17:07.404Z","unformatted_trans_date":"13-06-2020","customer":{"_id":"5ed3d67b8723c11444c43283","name":"Elizabeth Agusto"},"account":{"_id":"5ee5029f5a297caf4ce25ef3","name":"Checking Account"},"env":"production-sandbox","bank":{"name":"Guaranty Trust Bank","logo":"https://okra-images.s3.eu-west-3.amazonaws.com/GT+Bank.svg","icon":"https://okra-images.s3.eu-west-3.amazonaws.com/Guaranty+Trust+Bank+Logo+Color.svg","status":"healthy"},"created_at":"2020-06-13T16:46:09.369Z","last_updated":"2020-06-13T16:46:09.100Z","__v":0},{"notes":{"topics":["c"],"places":["a"],"people":["a"],"actions":["b"],"subjects":["b"],"preopositions":["a"],"desc":"Sapiente quis quisquam a saepe rerum."},"fetched":["5eda1df311475d0826ac1850"],"record":["5ee5028620ec110c6194f85d"],"_id":"5ee502d120ec110c6194f86e","branch":"ISJAGED1","cleared_date":"2020-06-13T10:52:14.577Z","unformatted_cleared_date":"12-06-2020","code":"a","credit":null,"debit":66967,"trans_date":"2020-06-12T20:15:34.206Z","unformatted_trans_date":"13-06-2020","customer":{"_id":"5ed3d67b8723c11444c43283","name":"Elizabeth Agusto"},"account":{"_id":"5ee5029f5a297caf4ce25ef3","name":"Checking Account"},"env":"production-sandbox","bank":{"name":"Guaranty Trust Bank","logo":"https://okra-images.s3.eu-west-3.amazonaws.com/GT+Bank.svg","icon":"https://okra-images.s3.eu-west-3.amazonaws.com/Guaranty+Trust+Bank+Logo+Color.svg","status":"healthy"},"created_at":"2020-06-13T16:46:09.129Z","last_updated":"2020-06-13T16:46:09.100Z","__v":0},{"notes":{"topics":["c"],"places":["b"],"people":["c"],"actions":["c"],"subjects":["b"],"preopositions":["b"],"desc":"Et pariatur quo tempora pariatur aliquam facilis voluptatum."},"fetched":["5eda1df311475d0826ac1850"],"record":["5ee5028620ec110c6194f85d"],"_id":"5ee502d120ec110c6194f873","branch":"CBCONCF1","cleared_date":"2020-06-13T05:15:55.141Z","unformatted_cleared_date":"12-06-2020","code":"p","credit":null,"debit":30828,"trans_date":"2020-06-12T22:37:44.038Z","unformatted_trans_date":"13-06-2020","customer":{"_id":"5ed3d67b8723c11444c43283","name":"Elizabeth Agusto"},"account":{"_id":"5ee5029f5a297caf4ce25ef3","name":"Checking Account"},"env":"production-sandbox","bank":{"name":"Guaranty Trust Bank","logo":"https://okra-images.s3.eu-west-3.amazonaws.com/GT+Bank.svg","icon":"https://okra-images.s3.eu-west-3.amazonaws.com/Guaranty+Trust+Ban ...

# %%
Okra_Auth()

# %%
inp_dict = {
    'api_token' : 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU',
    'base_url' : 'https://api.okra.ng/sandbox/v1/'
}
okra_mod = Okra_Auth(inp_dict)

# %%
okra_mod.retrieve_auth()
# Out:
# {'status': 'success',
#  'message': 'Auths successfully retrieved',
#  'data': {'pagination': None,
#   'auths': [{'id': '5f03b2d4af4681496afdd7b4',
#     'validated': True,
#     'record': {'_id': '5f03b2c28b1d840dc57b7f41',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb9',
#       'name': 'Union Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ef09108658acd0d06ae06b9', 'name': 'Faith Severin'}},
#     'created_at': '2020-07-06T23:25:08.750Z',
#     'last_updated': '2020-07-06T23:25:08.750Z'},
#    {'id': '5f03aea1af4681496afc3c88',
#     'validated': True,
#     'record': {'_id': '5f03ae86ac55690d56c48c92',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebc', 'name': 'Wema Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec1df66cd5bde37d3238828', 'name': 'Maryam Savage'}},
#     'created_at': '2020-07-06T23:07:13.092Z',
#     'last_updated': '2020-07-06T23:07:13.092Z'},
#    {'id': '5f03ae0baf4681496afbcb42',
#     'validated': True,
#     'record': {'_id': '5f03adf6414c210d08ed6f2d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-07-06T23:04:43.370Z',
#     'last_updated': '2020-07-06T23:04:43.370Z'},
#    {'id': '5f03aca9af4681496afb4f4c',
#     'validated': True,
#     'record': {'_id': '5f03ac9ce167d80cd2514368',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec2', 'name': 'Zenith Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5e9d5dd3471ff50f735ad68a',
#       'name': 'Emmanuel Johnson'}},
#     'created_at': '2020-07-06T22:58:49.621Z',
#     'last_updated': '2020-07-06T22:58:49.621Z'},
#    {'id': '5f03a8cdaf4681496afaccb9',
#     'validated': True,
#     'record': {'_id': '5f03a8b95a63fd0c4a54cacb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Edith Pitt'}},
#     'created_at': '2020-07-06T22:42:21.904Z',
#     'last_updated': '2020-07-06T22:42:21.904Z'},
#    {'id': '5f039c38af4681496af81d30',
#     'validated': True,
#     'record': {'_id': '5f039c243103140b668e92fb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-07-06T21:48:40.407Z',
#     'last_updated': '2020-07-06T21:48:40.407Z'},
#    {'id': '5f004eaeaf4681496a14aad4',
#     'validated': True,
#     'record': {'_id': '5f004e4eef5d3058b46463a8',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeba', 'name': 'Keystone Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec552e534dce7257892ed79',
#       'name': 'Christina Patterson'}},
#     'created_at': '2020-07-04T09:41:02.528Z',
#     'last_updated': '2020-07-04T09:41:02.528Z'},
#    {'id': '5eede9aeb87f052d8dc5163e',
#     'validated': True,
#     'record': {'_id': '5eede99e5156602b05620833',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-20T10:49:18.524Z',
#     'last_updated': '2020-06-20T10:49:18.524Z'},
#    {'id': '5ee7cc255a297caf4c6d5704',
#     'validated': True,
#     'record': {'_id': '5ee7cc1678b6e314502cdca2',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec0', 'name': 'Access Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ede59514eb21a091d146ebf',
#       'name': 'Endurance Agusto'}},
#     'created_at': '2020-06-15T19:29:41.739Z',
#     'last_updated': '2020-06-15T19:29:41.739Z'},
#    {'id': '5ee63c5d5a297caf4c33302d',
#     'validated': True,
#     'record': {'_id': '5ee63c4f98584109765ba885',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb6', 'name': 'Stanbic IBTC Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5df75c17c4e02270a383fb0e', 'name': 'David Severin'}},
#     'created_at': '2020-06-14T15:03:57.629Z',
#     'last_updated': '2020-06-14T15:03:57.629Z'},
#    {'id': '5ee5029e5a297caf4ce25eb0',
#     'validated': True,
#     'record': {'_id': '5ee5028620ec110c6194f85d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-13T16:45:18.846Z',
#     'last_updated': '2020-06-13T16:45:18.846Z'},
#    {'id': '5ee4b9195a297caf4cd554ee',
#     'validated': True,
#     'record': {'_id': '5ee4b8e9a7226f24e36478c0',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-06-13T11:31:37.869Z',
#     'last_updated': '2020-06-13T11:31:37.869Z'},
#    {'id': '5ee4b4135a297caf4cd3a011',
#     'validated': True,
#     'record': {'_id': '5ee4b3b33d78a02417326ffa',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Edith Pitt'}},
#     'created_at': '2020-06-13T11:10:11.823Z',
#     'last_updated': '2020-06-13T11:10:11.823Z'},
#    {'id': '5ee4af985a297caf4ccdfd96',
#     'validated': True,
#     'record': {'_id': '5ee4af7496277920f91f0584',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb1',
#       'name': 'First Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ee07701a708af0c89a5463c',
#       'name': 'Annabelle Evans'}},
#     'created_at': '2020-06-13T10:51:04.066Z',
#     'last_updated': '2020-06-13T10:51:04.066Z'}]}}

# %%
Okra_Auth(inp_dict).retrieve_auth()
# Out:
# {'status': 'success',
#  'message': 'Auths successfully retrieved',
#  'data': {'pagination': None,
#   'auths': [{'id': '5f03b2d4af4681496afdd7b4',
#     'validated': True,
#     'record': {'_id': '5f03b2c28b1d840dc57b7f41',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb9',
#       'name': 'Union Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ef09108658acd0d06ae06b9', 'name': 'Faith Severin'}},
#     'created_at': '2020-07-06T23:25:08.750Z',
#     'last_updated': '2020-07-06T23:25:08.750Z'},
#    {'id': '5f03aea1af4681496afc3c88',
#     'validated': True,
#     'record': {'_id': '5f03ae86ac55690d56c48c92',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebc', 'name': 'Wema Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec1df66cd5bde37d3238828', 'name': 'Maryam Savage'}},
#     'created_at': '2020-07-06T23:07:13.092Z',
#     'last_updated': '2020-07-06T23:07:13.092Z'},
#    {'id': '5f03ae0baf4681496afbcb42',
#     'validated': True,
#     'record': {'_id': '5f03adf6414c210d08ed6f2d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-07-06T23:04:43.370Z',
#     'last_updated': '2020-07-06T23:04:43.370Z'},
#    {'id': '5f03aca9af4681496afb4f4c',
#     'validated': True,
#     'record': {'_id': '5f03ac9ce167d80cd2514368',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec2', 'name': 'Zenith Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5e9d5dd3471ff50f735ad68a',
#       'name': 'Emmanuel Johnson'}},
#     'created_at': '2020-07-06T22:58:49.621Z',
#     'last_updated': '2020-07-06T22:58:49.621Z'},
#    {'id': '5f03a8cdaf4681496afaccb9',
#     'validated': True,
#     'record': {'_id': '5f03a8b95a63fd0c4a54cacb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Edith Pitt'}},
#     'created_at': '2020-07-06T22:42:21.904Z',
#     'last_updated': '2020-07-06T22:42:21.904Z'},
#    {'id': '5f039c38af4681496af81d30',
#     'validated': True,
#     'record': {'_id': '5f039c243103140b668e92fb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-07-06T21:48:40.407Z',
#     'last_updated': '2020-07-06T21:48:40.407Z'},
#    {'id': '5f004eaeaf4681496a14aad4',
#     'validated': True,
#     'record': {'_id': '5f004e4eef5d3058b46463a8',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeba', 'name': 'Keystone Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec552e534dce7257892ed79',
#       'name': 'Christina Patterson'}},
#     'created_at': '2020-07-04T09:41:02.528Z',
#     'last_updated': '2020-07-04T09:41:02.528Z'},
#    {'id': '5eede9aeb87f052d8dc5163e',
#     'validated': True,
#     'record': {'_id': '5eede99e5156602b05620833',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-20T10:49:18.524Z',
#     'last_updated': '2020-06-20T10:49:18.524Z'},
#    {'id': '5ee7cc255a297caf4c6d5704',
#     'validated': True,
#     'record': {'_id': '5ee7cc1678b6e314502cdca2',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec0', 'name': 'Access Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ede59514eb21a091d146ebf',
#       'name': 'Endurance Agusto'}},
#     'created_at': '2020-06-15T19:29:41.739Z',
#     'last_updated': '2020-06-15T19:29:41.739Z'},
#    {'id': '5ee63c5d5a297caf4c33302d',
#     'validated': True,
#     'record': {'_id': '5ee63c4f98584109765ba885',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb6', 'name': 'Stanbic IBTC Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5df75c17c4e02270a383fb0e', 'name': 'David Severin'}},
#     'created_at': '2020-06-14T15:03:57.629Z',
#     'last_updated': '2020-06-14T15:03:57.629Z'},
#    {'id': '5ee5029e5a297caf4ce25eb0',
#     'validated': True,
#     'record': {'_id': '5ee5028620ec110c6194f85d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-13T16:45:18.846Z',
#     'last_updated': '2020-06-13T16:45:18.846Z'},
#    {'id': '5ee4b9195a297caf4cd554ee',
#     'validated': True,
#     'record': {'_id': '5ee4b8e9a7226f24e36478c0',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-06-13T11:31:37.869Z',
#     'last_updated': '2020-06-13T11:31:37.869Z'},
#    {'id': '5ee4b4135a297caf4cd3a011',
#     'validated': True,
#     'record': {'_id': '5ee4b3b33d78a02417326ffa',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Edith Pitt'}},
#     'created_at': '2020-06-13T11:10:11.823Z',
#     'last_updated': '2020-06-13T11:10:11.823Z'},
#    {'id': '5ee4af985a297caf4ccdfd96',
#     'validated': True,
#     'record': {'_id': '5ee4af7496277920f91f0584',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb1',
#       'name': 'First Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ee07701a708af0c89a5463c',
#       'name': 'Annabelle Evans'}},
#     'created_at': '2020-06-13T10:51:04.066Z',
#     'last_updated': '2020-06-13T10:51:04.066Z'}]}}

# %%
t = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU'
b_u = 'https://api.okra.ng/sandbox/v1/'
okra_mod = Okra_Auth(token=t, base_url=b_u)

# %%
okra_mod.headers
# Out:
# {'Content-Type': 'application/json',
#  'Authorization': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU'}

# %%
okra_mod.retrieve_auth()
# Out:
# {'status': 'success',
#  'message': 'Auths successfully retrieved',
#  'data': {'pagination': None,
#   'auths': [{'id': '5f03b2d4af4681496afdd7b4',
#     'validated': True,
#     'record': {'_id': '5f03b2c28b1d840dc57b7f41',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb9',
#       'name': 'Union Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ef09108658acd0d06ae06b9', 'name': 'Faith Severin'}},
#     'created_at': '2020-07-06T23:25:08.750Z',
#     'last_updated': '2020-07-06T23:25:08.750Z'},
#    {'id': '5f03aea1af4681496afc3c88',
#     'validated': True,
#     'record': {'_id': '5f03ae86ac55690d56c48c92',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebc', 'name': 'Wema Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec1df66cd5bde37d3238828', 'name': 'Maryam Savage'}},
#     'created_at': '2020-07-06T23:07:13.092Z',
#     'last_updated': '2020-07-06T23:07:13.092Z'},
#    {'id': '5f03ae0baf4681496afbcb42',
#     'validated': True,
#     'record': {'_id': '5f03adf6414c210d08ed6f2d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-07-06T23:04:43.370Z',
#     'last_updated': '2020-07-06T23:04:43.370Z'},
#    {'id': '5f03aca9af4681496afb4f4c',
#     'validated': True,
#     'record': {'_id': '5f03ac9ce167d80cd2514368',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec2', 'name': 'Zenith Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5e9d5dd3471ff50f735ad68a',
#       'name': 'Emmanuel Johnson'}},
#     'created_at': '2020-07-06T22:58:49.621Z',
#     'last_updated': '2020-07-06T22:58:49.621Z'},
#    {'id': '5f03a8cdaf4681496afaccb9',
#     'validated': True,
#     'record': {'_id': '5f03a8b95a63fd0c4a54cacb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Edith Pitt'}},
#     'created_at': '2020-07-06T22:42:21.904Z',
#     'last_updated': '2020-07-06T22:42:21.904Z'},
#    {'id': '5f039c38af4681496af81d30',
#     'validated': True,
#     'record': {'_id': '5f039c243103140b668e92fb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-07-06T21:48:40.407Z',
#     'last_updated': '2020-07-06T21:48:40.407Z'},
#    {'id': '5f004eaeaf4681496a14aad4',
#     'validated': True,
#     'record': {'_id': '5f004e4eef5d3058b46463a8',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeba', 'name': 'Keystone Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec552e534dce7257892ed79',
#       'name': 'Christina Patterson'}},
#     'created_at': '2020-07-04T09:41:02.528Z',
#     'last_updated': '2020-07-04T09:41:02.528Z'},
#    {'id': '5eede9aeb87f052d8dc5163e',
#     'validated': True,
#     'record': {'_id': '5eede99e5156602b05620833',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-20T10:49:18.524Z',
#     'last_updated': '2020-06-20T10:49:18.524Z'},
#    {'id': '5ee7cc255a297caf4c6d5704',
#     'validated': True,
#     'record': {'_id': '5ee7cc1678b6e314502cdca2',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec0', 'name': 'Access Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ede59514eb21a091d146ebf',
#       'name': 'Endurance Agusto'}},
#     'created_at': '2020-06-15T19:29:41.739Z',
#     'last_updated': '2020-06-15T19:29:41.739Z'},
#    {'id': '5ee63c5d5a297caf4c33302d',
#     'validated': True,
#     'record': {'_id': '5ee63c4f98584109765ba885',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb6', 'name': 'Stanbic IBTC Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5df75c17c4e02270a383fb0e', 'name': 'David Severin'}},
#     'created_at': '2020-06-14T15:03:57.629Z',
#     'last_updated': '2020-06-14T15:03:57.629Z'},
#    {'id': '5ee5029e5a297caf4ce25eb0',
#     'validated': True,
#     'record': {'_id': '5ee5028620ec110c6194f85d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-13T16:45:18.846Z',
#     'last_updated': '2020-06-13T16:45:18.846Z'},
#    {'id': '5ee4b9195a297caf4cd554ee',
#     'validated': True,
#     'record': {'_id': '5ee4b8e9a7226f24e36478c0',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-06-13T11:31:37.869Z',
#     'last_updated': '2020-06-13T11:31:37.869Z'},
#    {'id': '5ee4b4135a297caf4cd3a011',
#     'validated': True,
#     'record': {'_id': '5ee4b3b33d78a02417326ffa',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Edith Pitt'}},
#     'created_at': '2020-06-13T11:10:11.823Z',
#     'last_updated': '2020-06-13T11:10:11.823Z'},
#    {'id': '5ee4af985a297caf4ccdfd96',
#     'validated': True,
#     'record': {'_id': '5ee4af7496277920f91f0584',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb1',
#       'name': 'First Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ee07701a708af0c89a5463c',
#       'name': 'Annabelle Evans'}},
#     'created_at': '2020-06-13T10:51:04.066Z',
#     'last_updated': '2020-06-13T10:51:04.066Z'}]}}

# %%
class Okra_Balance():
    
    """
    returns the real-time balance for each of a record's accounts. 
    It can be used for existing Records that were added via any of Okra’s other products
    
    https://docs.okra.ng/products/balance
    
    Initialize with token and base_url(e.g 'https://api.okra.ng/sandbox/v1/')
    """
    
    __init__ = Okra_Auth.__init__
    
    
    def retrieve_balance(self):
        
        """
        Retrieve Bank balance

        Returns: Json Response
        """
        url = self.base_url + "products/balances"
        resp = self.requests.post(url, headers = self.headers)
        return resp.json()
    
    
    def getbyID(self, idx, page=1, limit=1):
        
        """
        
        fetch balance info using the id of the balance.
        
        Args : "idx" (string)
        
        """
        url = self.base_url + "balance/getById"
        data_ = {"id": idx, "page": page, "limit":limit}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyOptions(self, first_name, last_name, page=1, limit=1):
        """
        fetch balance info using the options metadata you provided when setting up the widget.
        
        Args : "first_name" (string): "Uchencho",
               "last_name" (string): "Nwa Alozie"
        """
        url = self.base_url + "balance/byOptions"
        data_ = {"page": page, "limit":limit, 
                "options":{"first_name": first_name, "last_name": last_name}}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyCustomer(self, customer_id, page=1, limit=1):
        """
        
        fetch balance info using the customer id.
        
        Args : "customer_id" (string)
        
        """
        url = self.base_url + "balance/getByCustomer"
        data_ = {"page": page, "limit":limit, "customer":customer_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()

# %%
okra_bal = Okra_Balance(t, b_u)

# %%
Okra_Balance(t, b_u).base_url
# Out:
# 'https://api.okra.ng/sandbox/v1/'

# %%
okra_bal.retrieve_balance()
# Out:
# {'status': 'success',
#  'message': 'Balances successfully retrieved',
#  'data': {'pagination': None,
#   'balances': [{'id': '5f03b2d5af4681496afdd84f',
#     'account': {'_id': '5f03b2d5af4681496afdd804',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb9',
#       'name': 'Union Bank of Nigeria'},
#      'nuban': 'PS77037500',
#      'name': 'Home Loan Account'},
#     'ledger_balance': 2352.8,
#     'available_balance': 46950,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T23:25:09.065Z',
#     'last_updated': '2020-07-06T23:25:09.065Z'},
#    {'id': '5f03b2d5af4681496afdd849',
#     'account': {'_id': '5f03b2d5af4681496afdd7f9',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb9',
#       'name': 'Union Bank of Nigeria'},
#      'nuban': 'SE42739892',
#      'name': 'Checking Account'},
#     'ledger_balance': 7695.9,
#     'available_balance': 31370,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T23:25:09.058Z',
#     'last_updated': '2020-07-06T23:25:09.058Z'},
#    {'id': '5f03aea1af4681496afc3d28',
#     'account': {'_id': '5f03aea1af4681496afc3cd4',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebc', 'name': 'Wema Bank'},
#      'nuban': 'MU35WCHM74',
#      'name': 'Savings Account'},
#     'ledger_balance': 6298.9,
#     'available_balance': 34960,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T23:07:13.654Z',
#     'last_updated': '2020-07-06T23:08:06.134Z'},
#    {'id': '5f03aea1af4681496afc3d1b',
#     'account': {'_id': '5f03aea1af4681496afc3cc9',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebc', 'name': 'Wema Bank'},
#      'nuban': 'XK39089200',
#      'name': 'Personal Loan Account'},
#     'ledger_balance': 847,
#     'available_balance': 31630,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T23:07:13.645Z',
#     'last_updated': '2020-07-06T23:07:13.645Z'},
#    {'id': '5f03ae0baf4681496afbcbd7',
#     'account': {'_id': '5f03ae0baf4681496afbcb8f',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'nuban': 'BA35316415',
#      'name': 'Auto Loan Account'},
#     'ledger_balance': 5921.2,
#     'available_balance': 96080,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T23:04:43.758Z',
#     'last_updated': '2020-07-06T23:06:09.393Z'},
#    {'id': '5f03ae0baf4681496afbcbe8',
#     'account': {'_id': '5f03ae0baf4681496afbcb84',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'nuban': 'PK33KM1816',
#      'name': 'Credit Card Account'},
#     'ledger_balance': 6579.1,
#     'available_balance': 72990,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T23:04:43.801Z',
#     'last_updated': '2020-07-06T23:04:43.801Z'},
#    {'id': '5f03acaaaf4681496afb500b',
#     'account': {'_id': '5f03aca9af4681496afb4fbb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec2', 'name': 'Zenith Bank'},
#      'nuban': 'IL88540096',
#      'name': 'Investment Account'},
#     'ledger_balance': 5850.1,
#     'available_balance': 68030,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T22:58:50.040Z',
#     'last_updated': '2020-07-06T22:59:00.295Z'},
#    {'id': '5f03acaaaf4681496afb5016',
#     'account': {'_id': '5f03aca9af4681496afb4fc6',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec2', 'name': 'Zenith Bank'},
#      'nuban': 'KW20OIPC59',
#      'name': 'Credit Card Account'},
#     'ledger_balance': 3753.3,
#     'available_balance': 79470,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T22:58:50.049Z',
#     'last_updated': '2020-07-06T22:58:50.049Z'},
#    {'id': '5f03a8ceaf4681496afacd46',
#     'account': {'_id': '5f03a8ceaf4681496afacd06',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'nuban': 'LI70550515',
#      'name': 'Home Loan Account'},
#     'ledger_balance': 1469.6,
#     'available_balance': 50190,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T22:42:22.284Z',
#     'last_updated': '2020-07-06T22:42:25.568Z'},
#    {'id': '5f03a8ceaf4681496afacd48',
#     'account': {'_id': '5f03a8ceaf4681496afaccfb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'nuban': 'IS35308032',
#      'name': 'Investment Account'},
#     'ledger_balance': 2570.2,
#     'available_balance': 15390,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T22:42:22.286Z',
#     'last_updated': '2020-07-06T22:42:22.286Z'},
#    {'id': '5f039c38af4681496af81dbc',
#     'account': {'_id': '5f039c38af4681496af81d72',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'nuban': 'EE36000500',
#      'name': 'Investment Account'},
#     'ledger_balance': 9734.6,
#     'available_balance': 80850,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T21:48:40.817Z',
#     'last_updated': '2020-07-06T21:48:47.505Z'},
#    {'id': '5f039c38af4681496af81dbf',
#     'account': {'_id': '5f039c38af4681496af81d7d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'nuban': 'FI22464913',
#      'name': 'Investment Account'},
#     'ledger_balance': 5195.2,
#     'available_balance': 23570,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-06T21:48:40.820Z',
#     'last_updated': '2020-07-06T21:48:40.820Z'},
#    {'id': '5f004eafaf4681496a14ab75',
#     'account': {'_id': '5f004eafaf4681496a14ab29',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeba', 'name': 'Keystone Bank'},
#      'nuban': 'FO78100700',
#      'name': 'Checking Account'},
#     'ledger_balance': 5717,
#     'available_balance': 16170,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-04T09:41:03.585Z',
#     'last_updated': '2020-07-04T09:41:07.278Z'},
#    {'id': '5f004eafaf4681496a14ab71',
#     'account': {'_id': '5f004eafaf4681496a14ab1e',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeba', 'name': 'Keystone Bank'},
#      'nuban': 'SK46036769',
#      'name': 'Investment Account'},
#     'ledger_balance': 3949.8,
#     'available_balance': 75000,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-07-04T09:41:03.581Z',
#     'last_updated': '2020-07-04T09:41:03.581Z'},
#    {'id': '5eede9aeb87f052d8dc5172f',
#     'account': {'_id': '5eede9aeb87f052d8dc516e0',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'nuban': 'SE67007009',
#      'name': 'Savings Account'},
#     'ledger_balance': 9075,
#     'available_balance': 2650,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-20T10:49:18.972Z',
#     'last_updated': '2020-06-20T10:51:04.417Z'},
#    {'id': '5eede9aeb87f052d8dc51725',
#     'account': {'_id': '5eede9aeb87f052d8dc516d5',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'nuban': 'IT66P14200',
#      'name': 'Credit Card Account'},
#     'ledger_balance': 717.6,
#     'available_balance': 28300,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-20T10:49:18.966Z',
#     'last_updated': '2020-06-20T10:49:18.966Z'},
#    {'id': '5ee7cc265a297caf4c6d5788',
#     'account': {'_id': '5ee7cc265a297caf4c6d573d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec0', 'name': 'Access Bank'},
#      'nuban': 'BH25XPDZ65',
#      'name': 'Investment Account'},
#     'ledger_balance': 4180.7,
#     'available_balance': 96210,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-15T19:29:42.319Z',
#     'last_updated': '2020-06-15T19:29:44.694Z'},
#    {'id': '5ee7cc265a297caf4c6d5776',
#     'account': {'_id': '5ee7cc265a297caf4c6d5749',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec0', 'name': 'Access Bank'},
#      'nuban': 'PS33LY6566',
#      'name': 'Investment Account'},
#     'ledger_balance': 3818.5,
#     'available_balance': 13170,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-15T19:29:42.272Z',
#     'last_updated': '2020-06-15T19:29:42.272Z'},
#    {'id': '5ee63c5d5a297caf4c3330b8',
#     'account': {'_id': '5ee63c5d5a297caf4c33306d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb6', 'name': 'Stanbic IBTC Bank'},
#      'nuban': 'RS38552653',
#      'name': 'Investment Account'},
#     'ledger_balance': 4952.8,
#     'available_balance': 14190,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-14T15:03:57.950Z',
#     'last_updated': '2020-06-14T15:04:01.982Z'},
#    {'id': '5ee63c5d5a297caf4c3330c8',
#     'account': {'_id': '5ee63c5d5a297caf4c333078',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb6', 'name': 'Stanbic IBTC Bank'},
#      'nuban': 'MR67438434',
#      'name': 'Money Market Account'},
#     'ledger_balance': 5386.1,
#     'available_balance': 53880,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-14T15:03:57.957Z',
#     'last_updated': '2020-06-14T15:03:57.957Z'},
#    {'id': '5ee5029f5a297caf4ce25f3a',
#     'account': {'_id': '5ee5029f5a297caf4ce25ef3',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'nuban': 'AL49008695',
#      'name': 'Checking Account'},
#     'ledger_balance': 3642.1,
#     'available_balance': 34280,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-13T16:45:19.081Z',
#     'last_updated': '2020-06-13T16:45:47.160Z'},
#    {'id': '5ee5029f5a297caf4ce25f32',
#     'account': {'_id': '5ee5029f5a297caf4ce25ee8',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'nuban': 'SA49213A68',
#      'name': 'Checking Account'},
#     'ledger_balance': 9530.1,
#     'available_balance': 10950,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-13T16:45:19.075Z',
#     'last_updated': '2020-06-13T16:45:19.075Z'},
#    {'id': '5ee4b91a5a297caf4cd5557d',
#     'account': {'_id': '5ee4b91a5a297caf4cd5553d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'nuban': 'GB70SKFJ30',
#      'name': 'Credit Card Account'},
#     'ledger_balance': 8076.6,
#     'available_balance': 97570,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-13T11:31:38.558Z',
#     'last_updated': '2020-06-13T11:31:47.813Z'},
#    {'id': '5ee4b91a5a297caf4cd55585',
#     'account': {'_id': '5ee4b91a5a297caf4cd55532',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'nuban': 'DK20802484',
#      'name': 'Credit Card Account'},
#     'ledger_balance': 8486.3,
#     'available_balance': 50540,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-13T11:31:38.564Z',
#     'last_updated': '2020-06-13T11:31:38.564Z'},
#    {'id': '5ee4b4145a297caf4cd3a0a4',
#     'account': {'_id': '5ee4b4145a297caf4cd3a053',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'nuban': 'IS75068095',
#      'name': 'Investment Account'},
#     'ledger_balance': 5850.3,
#     'available_balance': 21870,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-13T11:10:12.131Z',
#     'last_updated': '2020-06-13T11:10:16.616Z'},
#    {'id': '5ee4b4145a297caf4cd3a0af',
#     'account': {'_id': '5ee4b4145a297caf4cd3a05e',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'nuban': 'IE11000025',
#      'name': 'Money Market Account'},
#     'ledger_balance': 6169.8,
#     'available_balance': 31540,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-13T11:10:12.145Z',
#     'last_updated': '2020-06-13T11:10:12.145Z'},
#    {'id': '5ee4af995a297caf4cce0bc7',
#     'account': {'_id': '5ee4af995a297caf4cce0b5a',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb1',
#       'name': 'First Bank of Nigeria'},
#      'nuban': 'GT18642S44',
#      'name': 'Investment Account'},
#     'ledger_balance': 3368.5,
#     'available_balance': 68170,
#     'currency': 'NGN',
#     'connected': True,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-13T10:51:05.358Z',
#     'last_updated': '2020-06-13T10:51:15.287Z'},
#    {'id': '5ee4af995a297caf4cce0bc4',
#     'account': {'_id': '5ee4af995a297caf4cce0b88',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb1',
#       'name': 'First Bank of Nigeria'},
#      'nuban': 'TN92002727',
#      'name': 'Credit Card Account'},
#     'ledger_balance': 7776.3,
#     'available_balance': 69130,
#     'currency': 'NGN',
#     'connected': False,
#     'env': 'production-sandbox',
#     'created_at': '2020-06-13T10:51:05.356Z',
#     'last_updated': '2020-06-13T10:51:05.356Z'}]}}

# %%
okra_bal.getbyCustomer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-5c6415c2abc6> in <module>
# ----> 1 okra_bal.getbyCustomer()
#
# TypeError: getbyCustomer() missing 1 required positional argument: 'customer_id'

# %%
from settings.py import token
t = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU'
b_u = 'https://api.okra.ng/sandbox/v1/'

# %%
class Okra_Auth():
    """
    Okra offers a path for a customer to successfully verify their bank. 
    The customer enters their credentials and are authenticated immediately.
    
    https://docs.okra.ng/products/auth

    Initialize with token and base_url(e.g 'https://api.okra.ng/sandbox/v1/')
    """
    
    def __init__(self, token, base_url='https://api.okra.ng/sandbox/v1/'):
        
        """
        Import requests on initialization
        Set the headers based on api token
        Set needed attributes
        """
        
        import requests
        
        self.api_token = token
        self.base_url = base_url
        self.headers = {'Content-Type': 'application/json',
                          'Authorization' : self.api_token}
        self.requests = requests
     
    def retrieve_auth(self):
        
        """
        Retrieve Bank details
        """
        url = self.base_url + "products/auths"
        resp = self.requests.post(url, headers = self.headers)
        return resp.json()
    
    
    def getbyID(self, idx, page=1, limit=1):
        
        """
        fetch authentication info using the id of the authentication record.
        
        Args : "idx" (string): "5rggfdfghjkl4567"
        """
        url = self.base_url + "auth/getById"
        data_ = {"id": idx, "page": page, "limit":limit}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyOptions(self, first_name, last_name, page=1, limit=1):
        """
        fetch authentication info using the options metadata you provided when setting up the widget.
        
        Args : "first_name" (string): "Uchencho",
               "last_name" (string): "Nwa Alozie"
        """
        url = self.base_url + "auth/byOptions"
        data_ = {"page": page, "limit":limit, 
                "options":{"first_name": first_name, "last_name": last_name}}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyCustomer(self, customer_id, page=1, limit=1):
        """
        fetch authentication info using the customer id.
        
        Args : "customer_id" (string): "5rggfdfghjkl4567",
        """
        url = self.base_url + "auth/getByCustomer"
        data_ = {"page": page, "limit":limit, "customer":customer_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyDate(self, from_, to_, page=1, limit=1):
        """
        fetch authentication info using a date range.
        
        Args : "to_" (string): "2020-4-02",
                "from_" (string): "2020-01-01"
        """
        url = self.base_url + "auth/getByDate"
        data_ = {"page": page, "limit":limit, "to":to_, "from":from_}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyBank(self, bank_id, page=1, limit=1):
        """
        fetch authentication info using the bank id.
        
        Args : "bank_id" (string): "5rggfdfghjkl4567",
        """
        url = self.base_url + "auth/getByBank"
        data_ = {"page": page, "limit":limit, "bank":bank_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyCustomerDate(self, customer_id, from_, to_, page=1, limit=1):
        """
        fetch authentication for a customer using a date range and customer id.
        
        Args : "customer":"5rggfdfghjkl4567",
                "to_" (string): "2020-4-02",
                "from_" (string): "2020-01-01"
        """
        url = self.base_url + "auth/getByDateCustomer"
        data_ = {"page": page, "limit":limit, "to":to_, "from":from_, "customer":customer_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()

# %%
# from settings.py import token
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU'

# %%
ok_mod = Okra_Auth(token, )

# %%
ok_mod.retrieve_auth()
# Out:
# {'status': 'success',
#  'message': 'Auths successfully retrieved',
#  'data': {'pagination': None,
#   'auths': [{'id': '5f03b2d4af4681496afdd7b4',
#     'validated': True,
#     'record': {'_id': '5f03b2c28b1d840dc57b7f41',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb9',
#       'name': 'Union Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ef09108658acd0d06ae06b9', 'name': 'Faith Severin'}},
#     'created_at': '2020-07-06T23:25:08.750Z',
#     'last_updated': '2020-07-06T23:25:08.750Z'},
#    {'id': '5f03aea1af4681496afc3c88',
#     'validated': True,
#     'record': {'_id': '5f03ae86ac55690d56c48c92',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebc', 'name': 'Wema Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec1df66cd5bde37d3238828', 'name': 'Maryam Savage'}},
#     'created_at': '2020-07-06T23:07:13.092Z',
#     'last_updated': '2020-07-06T23:07:13.092Z'},
#    {'id': '5f03ae0baf4681496afbcb42',
#     'validated': True,
#     'record': {'_id': '5f03adf6414c210d08ed6f2d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-07-06T23:04:43.370Z',
#     'last_updated': '2020-07-06T23:04:43.370Z'},
#    {'id': '5f03aca9af4681496afb4f4c',
#     'validated': True,
#     'record': {'_id': '5f03ac9ce167d80cd2514368',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec2', 'name': 'Zenith Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5e9d5dd3471ff50f735ad68a',
#       'name': 'Emmanuel Johnson'}},
#     'created_at': '2020-07-06T22:58:49.621Z',
#     'last_updated': '2020-07-06T22:58:49.621Z'},
#    {'id': '5f03a8cdaf4681496afaccb9',
#     'validated': True,
#     'record': {'_id': '5f03a8b95a63fd0c4a54cacb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Jane Johnson'}},
#     'created_at': '2020-07-06T22:42:21.904Z',
#     'last_updated': '2020-07-06T22:42:21.904Z'},
#    {'id': '5f039c38af4681496af81d30',
#     'validated': True,
#     'record': {'_id': '5f039c243103140b668e92fb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-07-06T21:48:40.407Z',
#     'last_updated': '2020-07-06T21:48:40.407Z'},
#    {'id': '5f004eaeaf4681496a14aad4',
#     'validated': True,
#     'record': {'_id': '5f004e4eef5d3058b46463a8',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeba', 'name': 'Keystone Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec552e534dce7257892ed79',
#       'name': 'Christina Patterson'}},
#     'created_at': '2020-07-04T09:41:02.528Z',
#     'last_updated': '2020-07-04T09:41:02.528Z'},
#    {'id': '5eede9aeb87f052d8dc5163e',
#     'validated': True,
#     'record': {'_id': '5eede99e5156602b05620833',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-20T10:49:18.524Z',
#     'last_updated': '2020-06-20T10:49:18.524Z'},
#    {'id': '5ee7cc255a297caf4c6d5704',
#     'validated': True,
#     'record': {'_id': '5ee7cc1678b6e314502cdca2',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec0', 'name': 'Access Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ede59514eb21a091d146ebf',
#       'name': 'Endurance Agusto'}},
#     'created_at': '2020-06-15T19:29:41.739Z',
#     'last_updated': '2020-06-15T19:29:41.739Z'},
#    {'id': '5ee63c5d5a297caf4c33302d',
#     'validated': True,
#     'record': {'_id': '5ee63c4f98584109765ba885',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb6', 'name': 'Stanbic IBTC Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5df75c17c4e02270a383fb0e', 'name': 'David Severin'}},
#     'created_at': '2020-06-14T15:03:57.629Z',
#     'last_updated': '2020-06-14T15:03:57.629Z'},
#    {'id': '5ee5029e5a297caf4ce25eb0',
#     'validated': True,
#     'record': {'_id': '5ee5028620ec110c6194f85d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-13T16:45:18.846Z',
#     'last_updated': '2020-06-13T16:45:18.846Z'},
#    {'id': '5ee4b9195a297caf4cd554ee',
#     'validated': True,
#     'record': {'_id': '5ee4b8e9a7226f24e36478c0',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-06-13T11:31:37.869Z',
#     'last_updated': '2020-06-13T11:31:37.869Z'},
#    {'id': '5ee4b4135a297caf4cd3a011',
#     'validated': True,
#     'record': {'_id': '5ee4b3b33d78a02417326ffa',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Jane Johnson'}},
#     'created_at': '2020-06-13T11:10:11.823Z',
#     'last_updated': '2020-06-13T11:10:11.823Z'},
#    {'id': '5ee4af985a297caf4ccdfd96',
#     'validated': True,
#     'record': {'_id': '5ee4af7496277920f91f0584',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb1',
#       'name': 'First Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ee07701a708af0c89a5463c',
#       'name': 'Joseph Johnson'}},
#     'created_at': '2020-06-13T10:51:04.066Z',
#     'last_updated': '2020-06-13T10:51:04.066Z'}]}}

# %%
ok_mod.getbyID()

# %%
class Initializer():

    def __init__(self, token, base_url='https://api.okra.ng/sandbox/v1/', prod_url=None):
        
        """
        Import requests on initialization
        Set the headers based on api token
        Set needed attributes
        """
        
        import requests
        
        self.api_token = token
        if prod_url is None:
            self.base_url = base_url
        else:
            self.base_url = prod_url
        self.headers = {'Content-Type': 'application/json',
                          'Authorization' : self.api_token}
        self.requests = requests

# %%
class Okra_Auth(Initializer):
    """
    Okra offers a path for a customer to successfully verify their bank. 
    The customer enters their credentials and are authenticated immediately.
    
    https://docs.okra.ng/products/auth

    Initialize with token and base_url(e.g 'https://api.okra.ng/sandbox/v1/')
    """
     
    def retrieve_auth(self):
        
        """
        Retrieve Bank details
        """
        url = self.base_url + "products/auths"
        resp = self.requests.post(url, headers = self.headers)
        return resp.json()
    
    
    def getbyID(self, idx, page=1, limit=20):
        
        """
        fetch authentication info using the id of the authentication record.
        
        Args : "idx" (string): "5rggfdfghjkl4567"
        """
        url = self.base_url + "auth/getById"
        data_ = {"id": idx, "page": page, "limit":limit}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyOptions(self, first_name, last_name, page=1, limit=20):
        """
        fetch authentication info using the options metadata you provided when setting up the widget.
        
        Args : "first_name" (string): "Uchencho",
               "last_name" (string): "Nwa Alozie"
        """
        url = self.base_url + "auth/byOptions"
        data_ = {"page": page, "limit":limit, 
                "options":{"first_name": first_name, "last_name": last_name}}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyCustomer(self, customer_id, page=1, limit=20, **kwargs):
        """
        fetch authentication info using the customer id.
        
        Args : "customer_id" (string): "5rggfdfghjkl4567",
        """
        url = self.base_url + "auth/getByCustomer"
        data_ = {"page": page, "limit":limit, "customer":customer_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyDate(self, from_, to_, page=1, limit=20):
        """
        fetch authentication info using a date range.
        
        Args : "to_" (string): "2020-4-02",
                "from_" (string): "2020-01-01"
        """
        url = self.base_url + "auth/getByDate"
        data_ = {"page": page, "limit":limit, "to":to_, "from":from_}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyBank(self, bank_id, page=1, limit=20):
        """
        fetch authentication info using the bank id.
        
        Args : "bank_id" (string): "5rggfdfghjkl4567",
        """
        url = self.base_url + "auth/getByBank"
        data_ = {"page": page, "limit":limit, "bank":bank_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()
    
    
    def getbyCustomerDate(self, customer_id, from_, to_, page=1, limit=20):
        """
        fetch authentication for a customer using a date range and customer id.
        
        Args : "customer":"5rggfdfghjkl4567",
                "to_" (string): "2020-4-02",
                "from_" (string): "2020-01-01"
        """
        url = self.base_url + "auth/getByDateCustomer"
        data_ = {"page": page, "limit":limit, "to":to_, "from":from_, "customer":customer_id}
        resp = self.requests.post(url, headers = headers, json=data_)
        return resp.json()

# %%
ok_mod = Okra_Auth(token)

# %%
ok_mod.retrieve_auth()
# Out:
# {'status': 'success',
#  'message': 'Auths successfully retrieved',
#  'data': {'pagination': None,
#   'auths': [{'id': '5f03b2d4af4681496afdd7b4',
#     'validated': True,
#     'record': {'_id': '5f03b2c28b1d840dc57b7f41',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb9',
#       'name': 'Union Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ef09108658acd0d06ae06b9', 'name': 'Faith Severin'}},
#     'created_at': '2020-07-06T23:25:08.750Z',
#     'last_updated': '2020-07-06T23:25:08.750Z'},
#    {'id': '5f03aea1af4681496afc3c88',
#     'validated': True,
#     'record': {'_id': '5f03ae86ac55690d56c48c92',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebc', 'name': 'Wema Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec1df66cd5bde37d3238828', 'name': 'Maryam Savage'}},
#     'created_at': '2020-07-06T23:07:13.092Z',
#     'last_updated': '2020-07-06T23:07:13.092Z'},
#    {'id': '5f03ae0baf4681496afbcb42',
#     'validated': True,
#     'record': {'_id': '5f03adf6414c210d08ed6f2d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-07-06T23:04:43.370Z',
#     'last_updated': '2020-07-06T23:04:43.370Z'},
#    {'id': '5f03aca9af4681496afb4f4c',
#     'validated': True,
#     'record': {'_id': '5f03ac9ce167d80cd2514368',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec2', 'name': 'Zenith Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5e9d5dd3471ff50f735ad68a',
#       'name': 'Emmanuel Johnson'}},
#     'created_at': '2020-07-06T22:58:49.621Z',
#     'last_updated': '2020-07-06T22:58:49.621Z'},
#    {'id': '5f03a8cdaf4681496afaccb9',
#     'validated': True,
#     'record': {'_id': '5f03a8b95a63fd0c4a54cacb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Jane Johnson'}},
#     'created_at': '2020-07-06T22:42:21.904Z',
#     'last_updated': '2020-07-06T22:42:21.904Z'},
#    {'id': '5f039c38af4681496af81d30',
#     'validated': True,
#     'record': {'_id': '5f039c243103140b668e92fb',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-07-06T21:48:40.407Z',
#     'last_updated': '2020-07-06T21:48:40.407Z'},
#    {'id': '5f004eaeaf4681496a14aad4',
#     'validated': True,
#     'record': {'_id': '5f004e4eef5d3058b46463a8',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeba', 'name': 'Keystone Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ec552e534dce7257892ed79',
#       'name': 'Christina Patterson'}},
#     'created_at': '2020-07-04T09:41:02.528Z',
#     'last_updated': '2020-07-04T09:41:02.528Z'},
#    {'id': '5eede9aeb87f052d8dc5163e',
#     'validated': True,
#     'record': {'_id': '5eede99e5156602b05620833',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-20T10:49:18.524Z',
#     'last_updated': '2020-06-20T10:49:18.524Z'},
#    {'id': '5ee7cc255a297caf4c6d5704',
#     'validated': True,
#     'record': {'_id': '5ee7cc1678b6e314502cdca2',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbec0', 'name': 'Access Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ede59514eb21a091d146ebf',
#       'name': 'Endurance Agusto'}},
#     'created_at': '2020-06-15T19:29:41.739Z',
#     'last_updated': '2020-06-15T19:29:41.739Z'},
#    {'id': '5ee63c5d5a297caf4c33302d',
#     'validated': True,
#     'record': {'_id': '5ee63c4f98584109765ba885',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb6', 'name': 'Stanbic IBTC Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5df75c17c4e02270a383fb0e', 'name': 'David Severin'}},
#     'created_at': '2020-06-14T15:03:57.629Z',
#     'last_updated': '2020-06-14T15:03:57.629Z'},
#    {'id': '5ee5029e5a297caf4ce25eb0',
#     'validated': True,
#     'record': {'_id': '5ee5028620ec110c6194f85d',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb3',
#       'name': 'Guaranty Trust Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ed3d67b8723c11444c43283',
#       'name': 'Endurance James'}},
#     'created_at': '2020-06-13T16:45:18.846Z',
#     'last_updated': '2020-06-13T16:45:18.846Z'},
#    {'id': '5ee4b9195a297caf4cd554ee',
#     'validated': True,
#     'record': {'_id': '5ee4b8e9a7226f24e36478c0',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#       'name': 'United Bank For Africa'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#     'created_at': '2020-06-13T11:31:37.869Z',
#     'last_updated': '2020-06-13T11:31:37.869Z'},
#    {'id': '5ee4b4135a297caf4cd3a011',
#     'validated': True,
#     'record': {'_id': '5ee4b3b33d78a02417326ffa',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Jane Johnson'}},
#     'created_at': '2020-06-13T11:10:11.823Z',
#     'last_updated': '2020-06-13T11:10:11.823Z'},
#    {'id': '5ee4af985a297caf4ccdfd96',
#     'validated': True,
#     'record': {'_id': '5ee4af7496277920f91f0584',
#      'bank': {'_id': '5d6fe57a4099cc4b210bbeb1',
#       'name': 'First Bank of Nigeria'},
#      'env': 'production-sandbox',
#      'owner': '5eda1df311475d0826ac1850',
#      'customer': {'_id': '5ee07701a708af0c89a5463c',
#       'name': 'Joseph Johnson'}},
#     'created_at': '2020-06-13T10:51:04.066Z',
#     'last_updated': '2020-06-13T10:51:04.066Z'}]}}

# %%
class MissingTokenError(Exception):
    """
    Missing Token Error
    """

# %%
class Initializer():

    def __init__(self, token=None, base_url='https://api.okra.ng/sandbox/v1/', prod_url=None):
        
        """
        Import requests on initialization
        Set the headers based on api token
        Set needed attributes
        """
        
        import requests

        if token is None:
            print("here")
            raise MissingTokenError("Token is necessary to initialize Module")
        
        self._api_token = token
        self._base_url = base_url if prod_url is None else prod_url
        self._headers = {'Content-Type': 'application/json',
                          'Authorization' : self._api_token}
        self._requests = requests



class Okra_Auth(Initializer):
    """
    Okra offers a path for a customer to successfully verify their bank. 
    The customer enters their credentials and are authenticated immediately.
    
    https://docs.okra.ng/products/auth

    Initialize with token and base_url(e.g 'https://api.okra.ng/sandbox/v1/')
    """

     
    def retrieve_auth(self):
        
        """
        Retrieve Bank details
        """
        url = self._base_url + "products/auths"
        resp = self._requests.post(url, headers = self._headers)
        return resp

# %%
# from settings.py import token
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI1ZWRhMWRmMzExNDc1ZDA4MjZhYzE4NTAiLCJpYXQiOjE1OTIwNDU5MzJ9.vtX1TvzDGcv61sQs4VIzdvFKiSNgmIubbLuYaNjh4LU'

# %%
ok_mod = Okra_Auth(token, prod_url="http://goal.com")

# %%
ok_mod.base_url
# Out:
# 'http://goal.com'

# %%
retrieve_resp = ok_mod.retrieve_auth()

# %%
retrieve_resp.status_code
# Out:
# 200

# %%
class OkraTransaction(Initializer):
    """
    allows developers to receive customer-authorized transaction data for current, savings, and domiciliary Accounts.
    
    docs link: https://docs.okra.ng/products/transactions
    
    Initialize with token and base_url(e.g 'https://api.okra.ng/sandbox/v1/')
    """

    def getTransactions(self):
        """
        Retrieve transactions

        Returns: Response object
        """
        url = self._base_url + "products/transactions"
        return self._requests.post(url, headers = self._headers)

# %%
okra_tx = OkraTransaction(token)

# %%
okra_tx.getTransactions().json()
# Out:
# {'status': 'success',
#  'message': 'Transaction Sets successfully retrieved',
#  'data': {'pagination': None,
#   'trans': [{'bank': {'_id': '5d6fe57a4099cc4b210bbeb1',
#      'name': 'First Bank of Nigeria'},
#     'count': 79,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5ee07701a708af0c89a5463c', 'name': 'Joseph Johnson'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#     'count': 59,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Jane Johnson'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#      'name': 'United Bank For Africa'},
#     'count': 52,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbec2', 'name': 'Zenith Bank'},
#     'count': 30,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5e9d5dd3471ff50f735ad68a',
#      'name': 'Emmanuel Johnson'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbebc', 'name': 'Wema Bank'},
#     'count': 66,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5ec1df66cd5bde37d3238828', 'name': 'Maryam Savage'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbebb',
#      'name': 'United Bank For Africa'},
#     'count': 81,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5defaec14ff9b30ae366483a', 'name': 'Ralph Simpson'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbeba', 'name': 'Keystone Bank'},
#     'count': 49,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5ec552e534dce7257892ed79',
#      'name': 'Christina Patterson'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbeb3', 'name': 'Guaranty Trust Bank'},
#     'count': 30,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5ed3d67b8723c11444c43283',
#      'name': 'Faith Rockfeller'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbeb3', 'name': 'Guaranty Trust Bank'},
#     'count': 33,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5ed3d67b8723c11444c43283',
#      'name': 'Faith Rockfeller'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbeb6', 'name': 'Stanbic IBTC Bank'},
#     'count': 19,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5df75c17c4e02270a383fb0e', 'name': 'Sunday Pitt'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbeb8', 'name': 'Sterling Bank'},
#     'count': 56,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5eae1ec8a400e208b3b888cd', 'name': 'Jane Johnson'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbec0', 'name': 'Access Bank'},
#     'count': 65,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5ede59514eb21a091d146ebf',
#      'name': 'Endurance Agusto'}},
#    {'bank': {'_id': '5d6fe57a4099cc4b210bbeb3', 'name': 'Guaranty Trust Bank'},
#     'count': 69,
#     'env': 'production-sandbox',
#     'customer': {'_id': '5ed3d67b8723c11444c43283',
#      'name': 'Faith Rockfeller'}}]}}
